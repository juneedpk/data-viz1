# %%
import pandas as pd
import numpy as np

import seaborn as sns

# df = pd.Series(['a','b','c','d'],index=[1,2,3,4])
df = pd.Series(['car','bus','train'],index=['a','b','c'])
df
# Out:
# a      car
# b      bus
# c    train
# dtype: object

# %%
data_mobile={'mobile':['samsung','nokia','google'],'color':['red','blue','green'],'price':[10,20,30]}

df=pd.DataFrame(data_mobile,columns=['mobile','color','price'])

df['market']=['hallroad','hafeezcenter','gulberg'] #addition of new column
df
# Out:
#     mobile  color  price        market
# 0  samsung    red     10      hallroad
# 1    nokia   blue     20  hafeezcenter
# 2   google  green     30       gulberg

# %%
pop = {'population':['male','female'],'color':['black','white'],'continent':['asia','africa']}

total =pd.DataFrame(pop,columns=['population','color','continent'])

total
# Out:
#   population  color continent
# 0       male  black      asia
# 1     female  white    africa

# %%
soil = {'temperature':[4,6,9.9,12,3],'color':['black','white','green','brown','yellow'],'height':[4,10,6,12,9]}

net =pd.DataFrame(soil,columns=['temperature','color','height'])


net.loc[[2,4],['color']]
# Out:
#     color
# 2   green
# 4  yellow

# %%
soil = ({'temperature':[4,6,9.9,12,3],'color':['black','white','green','brown','yellow'],'height':[4,10,6,12,9]})

net =pd.DataFrame(soil,columns=['temperature','color','height'])

net.loc

# %%
import pandas as pd
import numpy as np


fuel = pd.read_csv('FuelConsumption.csv')

fuel.loc[[3,8],['MODELYEAR','FUELTYPE']]

fuel.loc[3:,'TRANSMISSION':]

fuel.iloc[3:9,2:5]

fuel.iloc[4:,:6]
# Out:
#       MODELYEAR   MAKE     MODEL    VEHICLECLASS  ENGINESIZE  CYLINDERS
# 4          2014  ACURA   RDX AWD     SUV - SMALL         3.5          6
# 5          2014  ACURA       RLX        MID-SIZE         3.5          6
# 6          2014  ACURA        TL        MID-SIZE         3.5          6
# 7          2014  ACURA    TL AWD        MID-SIZE         3.7          6
# 8          2014  ACURA    TL AWD        MID-SIZE         3.7          6
# ...         ...    ...       ...             ...         ...        ...
# 1062       2014  VOLVO  XC60 AWD     SUV - SMALL         3.0          6
# 1063       2014  VOLVO  XC60 AWD     SUV - SMALL         3.2          6
# 1064       2014  VOLVO  XC70 AWD     SUV - SMALL         3.0          6
# 1065       2014  VOLVO  XC70 AWD     SUV - SMALL         3.2          6
# 1066       2014  VOLVO  XC90 AWD  SUV - STANDARD         3.2          6
#
# [1063 rows x 6 columns]

# %%
dates = pd.date_range('20220721',periods=12)

df =pd.DataFrame(np.random.randn(12,6),index=dates,columns=list('ABCDEF'))
df.transpose()
df.describe()
df.sort_index(axis=0,ascending=False)
df.sort_values(by='B',ascending=True)
df['D']
# Out:
# 2022-07-21    0.661925
# 2022-07-22    0.034310
# 2022-07-23   -1.539370
# 2022-07-24    1.114869
# 2022-07-25   -2.125437
# 2022-07-26   -0.695382
# 2022-07-27    0.116939
# 2022-07-28   -0.083970
# 2022-07-29   -0.540292
# 2022-07-30    0.677610
# 2022-07-31   -0.287416
# 2022-08-01   -1.090240
# Freq: D, Name: D, dtype: float64

# %%
import pandas as pd
import numpy as np
dates = pd.date_range(20220822,periods=9)
final = pd.DataFrame(np.random.randn(9,4),index=dates ,columns=list('ABCD'))
#dates shoul be in strings
final.iloc[3:6,:3] #slicing #implicity
final.loc[dates[1]]  #rowwise
final.loc[:,['A','B']] #columnwise
final.at[dates[4],'B'] #scaler value
final[final['A']>0] #boolean filtering

final[final>0]
# Out:
#                                       A         B         C         D
# 1970-01-01 00:00:00.020220822  0.153741  0.862340  0.520614       NaN
# 1970-01-02 00:00:00.020220822       NaN       NaN       NaN  0.097237
# 1970-01-03 00:00:00.020220822       NaN       NaN  1.457735       NaN
# 1970-01-04 00:00:00.020220822       NaN  1.011802  0.878704  0.194289
# 1970-01-05 00:00:00.020220822       NaN  0.886661       NaN  1.436132
# 1970-01-06 00:00:00.020220822       NaN  0.229019  0.744444  0.846888
# 1970-01-07 00:00:00.020220822  0.481665  0.339262  0.972633       NaN
# 1970-01-08 00:00:00.020220822  0.326554  3.237348       NaN  1.065098
# 1970-01-09 00:00:00.020220822       NaN       NaN       NaN       NaN

# %%
fuel.to_numpy() #TO NUMPY CONVERSION
# Out:
# array([[2014, 'ACURA', 'ILX', ..., 8.5, 33, 196],
#        [2014, 'ACURA', 'ILX', ..., 9.6, 29, 221],
#        [2014, 'ACURA', 'ILX HYBRID', ..., 5.9, 48, 136],
#        ...,
#        [2014, 'VOLVO', 'XC70 AWD', ..., 11.8, 24, 271],
#        [2014, 'VOLVO', 'XC70 AWD', ..., 11.3, 25, 260],
#        [2014, 'VOLVO', 'XC90 AWD', ..., 12.8, 22, 294]], dtype=object)

# %%
fuel.T
# Out:
#                              0        1           2            3     \
# MODELYEAR                    2014     2014        2014         2014
# MAKE                        ACURA    ACURA       ACURA        ACURA
# MODEL                         ILX      ILX  ILX HYBRID      MDX 4WD
# VEHICLECLASS              COMPACT  COMPACT     COMPACT  SUV - SMALL
# ENGINESIZE                    2.0      2.4         1.5          3.5
# CYLINDERS                       4        4           4            6
# TRANSMISSION                  AS5       M6         AV7          AS6
# FUELTYPE                        Z        Z           Z            Z
# FUELCONSUMPTION_CITY          9.9     11.2         6.0         12.7
# FUELCONSUMPTION_HWY           6.7      7.7         5.8          9.1
# FUELCONSUMPTION_COMB          8.5      9.6         5.9         11.1
# FUELCONSUMPTION_COMB_MPG       33       29          48           25
# CO2EMISSIONS                  196      221         136          255
#
#                                  4         5         6         7         8     \
# MODELYEAR                        2014      2014      2014      2014      2014
# MAKE                            ACURA     ACURA     ACURA     ACURA     ACURA
# MODEL                         RDX AWD       RLX        TL    TL AWD    TL AWD
# VEHICLECLASS              SUV - SMALL  MID-SIZE  MID-SIZE  MID-SIZE  MID-SIZE
# ENGINESIZE                        3.5       3.5       3.5       3.7       3.7
# CYLINDERS                           6         6         6         6         6
# TRANSMISSION                      AS6       AS6       AS6       AS6        M6
# FUELTYPE                            Z         Z         Z         Z         Z
# FUELCONSUMPTION_CITY             12.1      11.9      11.8      12.8      13.4
# FUELCONSUMPTION_HWY               8.7       7.7       8.1       9.0       9.5
# FUELCONSUMPTION_COMB             10.6      10.0      10.1      11.1      11.6
# FUELCONSUMPTION_COMB_MPG           27        28        28        25        24
# CO2EMISSIONS                      244       230       232       255       267
#
#                              9     ...     1057     1058      1059      1060  \
# MODELYEAR                    2014  ...     2014     2014      2014      2014
# MAKE                        ACURA  ...    VOLVO    VOLVO     VOLVO     VOLVO
# MODEL                         TSX  ...  S60 AWD  S60 AWD       S80   S80 AWD
# VEHICLECLASS              COMPACT  ...  COMPACT  COMPACT  MID-SIZE  MID-SIZE
# ENGINESIZE                    2.4  ...      2.5      3.0       3.2       3.0
# CYLINDERS                       4  ...        5        6         6         6
# TRANSMISSION                  AS5  ...      AS6      AS6       AS6       AS6
# FUELTYPE                        Z  ...        X        X         X         X
# FUELCONSUMPTION_CITY         10.6  ...     11.6     13.2      11.9      13.2
# FUELCONSUMPTION_HWY           7.5  ...      8.3      9.5       8.1       9.5
# FUELCONSUMPTION_COMB          9.2  ...     10.1     11.5      10.2      11.5
# FUELCONSUMPTION_COMB_MPG       31  ...       28       25        28        25
# CO2EMISSIONS                  212  ...      232      264       235       264
#
#                                  1061         1062         1063         1064  \
# MODELYEAR                        2014         2014         2014         2014
# MAKE                            VOLVO        VOLVO        VOLVO        VOLVO
# MODEL                            XC60     XC60 AWD     XC60 AWD     XC70 AWD
# VEHICLECLASS              SUV - SMALL  SUV - SMALL  SUV - SMALL  SUV - SMALL
# ENGINESIZE                        3.2          3.0          3.2          3.0
# CYLINDERS                           6            6            6            6
# TRANSMISSION                      AS6          AS6          AS6          AS6
# FUELTYPE                            X            X            X            X
# FUELCONSUMPTION_CITY             13.0         13.4         13.2         13.4
# FUELCONSUMPTION_HWY               8.9          9.8          9.5          9.8
# FUELCONSUMPTION_COMB             11.2         11.8         11.5         11.8
# FUELCONSUMPTION_COMB_MPG           25           24           25           24
# CO2EMISSIONS                      258          271          264          271
#
#                                  1065            1066
# MODELYEAR                        2014            2014
# MAKE                            VOLVO           VOLVO
# MODEL                        XC70 AWD        XC90 AWD
# VEHICLECLASS              SUV - SMALL  SUV - STANDARD
# ENGINESIZE                        3.2             3.2
# CYLINDERS                           6               6
# TRANSMISSION                      AS6             AS6
# FUELTYPE                            X               X
# FUELCONSUMPTION_CITY             12.9            14.9
# FUELCONSUMPTION_HWY               9.3            10.2
# FUELCONSUMPTION_COMB             11.3            12.8
# FUELCONSUMPTION_COMB_MPG           25              22
# CO2EMISSIONS                      260             294
#
# [13 rows x 1067 columns]

# %%
fuel.sort_index(axis=1,ascending=True)
fuel.sort_values(by='CYLINDERS', ascending=False)
fuel['TRANSMISSION']
# Out:
# 0       AS5
# 1        M6
# 2       AV7
# 3       AS6
# 4       AS6
#        ...
# 1062    AS6
# 1063    AS6
# 1064    AS6
# 1065    AS6
# 1066    AS6
# Name: TRANSMISSION, Length: 1067, dtype: object

# %%
fuel[fuel['ENGINESIZE']>4]
fuel[fuel['CYLINDERS']>8]
# Out:
#      MODELYEAR          MAKE                             MODEL  \
# 12        2014  ASTON MARTIN                               DB9
# 13        2014  ASTON MARTIN                            RAPIDE
# 18        2014  ASTON MARTIN                          VANQUISH
# 35        2014          AUDI                               A8L
# 46        2014          AUDI                                R8
# 47        2014          AUDI                                R8
# 50        2014          AUDI                         R8 SPYDER
# 51        2014          AUDI                         R8 SPYDER
# 69        2014       BENTLEY                    CONTINENTAL GT
# 71        2014       BENTLEY  CONTINENTAL GT SPEED CONVERTIBLE
# 73        2014       BENTLEY                   CONTINENTAL GTC
# 74        2014       BENTLEY                       FLYING SPUR
# 112       2014           BMW                             760Li
# 349       2014          FORD                        E350 WAGON
# 633       2014   LAMBORGHINI                   AVENTADOR COUPE
# 634       2014   LAMBORGHINI                    GALLARDO COUPE
# 635       2014   LAMBORGHINI                    GALLARDO COUPE
# 922       2014   ROLLS-ROYCE                             GHOST
# 923       2014   ROLLS-ROYCE                         GHOST EWB
# 924       2014   ROLLS-ROYCE                           PHANTOM
# 925       2014   ROLLS-ROYCE                     PHANTOM COUPE
# 926       2014   ROLLS-ROYCE            PHANTOM DROPHEAD COUPE
# 927       2014   ROLLS-ROYCE                       PHANTOM EWB
# 928       2014   ROLLS-ROYCE                            WRAITH
# 940       2014           SRT                       VIPER COUPE
# 941       2014           SRT                   VIPER GTS COUPE
#
#         VEHICLECLASS  ENGINESIZE  CYLINDERS TRANSMISSION FUELTYPE  \
# 12       MINICOMPACT         5.9         12           A6        Z
# 13        SUBCOMPACT         5.9         12           A6        Z
# 18       MINICOMPACT         5.9         12           A6        Z
# 35         FULL-SIZE         6.3         12          AS8        Z
# 46        TWO-SEATER         5.2         10           A7        Z
# 47        TWO-SEATER         5.2         10           M6        Z
# 50        TWO-SEATER         5.2         10           A7        Z
# 51        TWO-SEATER         5.2         10           M6        Z
# 69        SUBCOMPACT         6.0         12          AS8        Z
# 71        SUBCOMPACT         6.0         12          AS8        Z
# 73        SUBCOMPACT         6.0         12          AS8        Z
# 74          MID-SIZE         6.0         12          AS8        Z
# 112        FULL-SIZE         6.0         12           A8        Z
# 349  VAN - PASSENGER         6.8         10           A5        X
# 633       TWO-SEATER         6.5         12           A7        Z
# 634       TWO-SEATER         5.2         10           A6        Z
# 635       TWO-SEATER         5.2         10           M6        Z
# 922        FULL-SIZE         6.6         12           A8        Z
# 923        FULL-SIZE         6.6         12           A8        Z
# 924        FULL-SIZE         6.7         12           A8        Z
# 925          COMPACT         6.7         12           A8        Z
# 926          COMPACT         6.7         12           A8        Z
# 927        FULL-SIZE         6.7         12           A8        Z
# 928         MID-SIZE         6.6         12           A8        Z
# 940       TWO-SEATER         8.4         10           M6        Z
# 941       TWO-SEATER         8.4         10           M6        Z
#
#      FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  \
# 12                   18.0                 12.6                  15.6
# 13                   18.0                 12.6                  15.6
# 18                   18.0                 12.6                  15.6
# 35                   18.2                 12.6                  15.7
# 46                   18.8                 11.3                  15.4
# 47                   21.1                 13.8                  17.8
# 50                   18.8                 11.3                  15.4
# 51                   21.1                 13.8                  17.8
# 69                   18.8                 11.5                  15.5
# 71                   20.0                 12.2                  16.5
# 73                   20.0                 12.2                  16.5
# 74                   20.0                 12.2                  16.5
# 112                  18.7                 11.5                  15.5
# 349                  23.9                 17.8                  21.2
# 633                  22.8                 12.9                  18.3
# 634                  18.0                 12.8                  15.7
# 635                  20.6                 13.5                  17.4
# 922                  19.1                 12.3                  16.0
# 923                  19.1                 12.3                  16.0
# 924                  20.7                 12.8                  17.1
# 925                  20.7                 12.8                  17.1
# 926                  20.7                 12.7                  17.1
# 927                  20.7                 12.7                  17.1
# 928                  18.7                 11.8                  15.6
# 940                  20.0                 13.0                  16.9
# 941                  20.0                 13.0                  16.9
#
#      FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 12                         18           359
# 13                         18           359
# 18                         18           359
# 35                         18           361
# 46                         18           354
# 47                         16           409
# 50                         18           354
# 51                         16           409
# 69                         18           356
# 71                         17           380
# 73                         17           380
# 74                         17           380
# 112                        18           356
# 349                        13           488
# 633                        15           421
# 634                        18           361
# 635                        16           400
# 922                        18           368
# 923                        18           368
# 924                        17           393
# 925                        17           393
# 926                        17           393
# 927                        17           393
# 928                        18           359
# 940                        17           389
# 941                        17           389

# %%
fuel.loc[90,['MODEL','VEHICLECLASS','ENGINESIZE','MAKE','MODELYEAR']] #CROSS SECTION OF DATA.
# Out:
# MODEL           335i xDRIVE GRAN TURISMO
# VEHICLECLASS                   FULL-SIZE
# ENGINESIZE                           3.0
# MAKE                                 BMW
# MODELYEAR                           2014
# Name: 90, dtype: object

# %%
df=fuel.at[45,'MODEL']
df
# Out:
# 'R8'

# %%
cities = ({'place':['lahore','karachi','peshawer'],'weather':['rainy','cloudy','clear']})

df= pd.DataFrame(cities,columns=['place','weather'])

df['day']=['monday','friday','sunday']
df
# Out:
#       place weather     day
# 0    lahore   rainy  monday
# 1   karachi  cloudy  friday
# 2  peshawer   clear  sunday

# %%
fuel.loc[1:3,['CYLINDERS','MAKE']]
# Out:
#    CYLINDERS   MAKE
# 1          4  ACURA
# 2          4  ACURA
# 3          6  ACURA

# %%
# Out:
# C:\Users\AI\AppData\Roaming\Python\Python38\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\AI\Desktop\vscode-jupyter\pandas.ipynb Cell 17 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/AI/Desktop/vscode-jupyter/pandas.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> sns.countplot(fuel['CO2EMISSIONS']).unique()
#
# AttributeError: 'AxesSubplot' object has no attribute 'unique'

# %%
# Out:
# 35710
