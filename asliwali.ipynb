# %%
import matplotlib.pyplot as plt
import seaborn as sns

phool = sns.load_dataset("titanic")

# print(phool)

p = sns.barplot(y="who",x = "age",data=phool,hue='class',palette="dark")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
